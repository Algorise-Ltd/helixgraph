# %% [markdown]
# # HEL-21 NER Model Training on Google Colab
#
# This notebook trains the Named Entity Recognition model for the HelixGraph project.
#
# **Training Data:**
# - 680 training examples
# - 170 validation examples
# - 8 entity types: SUPPLIER, PRODUCT, CAMPAIGN, CONTRACT, PO, INVOICE, ROLE, SKILL
#
# **Model:** RoBERTa-base transformer with spaCy
#
# **Expected Training Time:**
# - CPU: 2-3 hours
# - GPU (T4): 30-45 minutes

# %% [markdown]
# ## Step 1: Mount Google Drive

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Navigate to project directory
PROJECT_PATH = '/content/drive/MyDrive/Helixgraph'

# Create project directory if it doesn't exist
# !mkdir -p "$PROJECT_PATH"

print(f"✅ Google Drive mounted")
print(f"📁 Project path: {PROJECT_PATH}")
# Out:
# Mounted at /content/drive
# ✅ Google Drive mounted
# 📁 Project path: /content/drive/MyDrive/Helixgraph

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
# Install spaCy with transformers support
# !pip install -U spacy[transformers]

# Download RoBERTa model
# !python -m spacy download en_core_web_trf

print("\n✅ Dependencies installed successfully!")
# Out:
# Requirement already satisfied: spacy[transformers] in /usr/local/lib/python3.12/dist-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (2.11.10)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy[transformers]) (25.0)
# Collecting spacy_transformers<1.4.0,>=1.1.2 (from spacy[transformers])
#   Downloading spacy_transformers-1.3.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy[transformers]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy[transformers]) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy[transformers]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy[transformers]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy[transformers]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy[transformers]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy[transformers]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy[transformers]) (2025.11.12)
# Collecting transformers<4.50.0,>=3.4.0 (from spacy_transformers<1.4.0,>=1.1.2->spacy[transformers])
#   Downloading transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (2.9.0+cu126)
# Collecting spacy-alignments<1.0.0,>=0.7.2 (from spacy_transformers<1.4.0,>=1.1.2->spacy[transformers])
#   Downloading spacy_alignments-0.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy[transformers]) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy[transformers]) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim<1.0.0,>=0.3.0->spacy[transformers]) (8.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy[transformers]) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy[transformers]) (7.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy[transformers]) (3.0.3)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy[transformers]) (2.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (3.5)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (3.5.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from transformers<4.50.0,>=3.4.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.50.0,>=3.4.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.50.0,>=3.4.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (2024.11.6)
# Collecting tokenizers<0.22,>=0.21 (from transformers<4.50.0,>=3.4.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers])
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.50.0,>=3.4.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers<4.50.0,>=3.4.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->spacy_transformers<1.4.0,>=1.1.2->spacy[transformers]) (1.3.0)
# Downloading spacy_transformers-1.3.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (795 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.8/795.8 kB 46.1 MB/s eta 0:00:00
# Downloading spacy_alignments-0.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 kB 23.3 MB/s eta 0:00:00
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 79.0 MB/s eta 0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 73.1 MB/s eta 0:00:00
# Installing collected packages: spacy-alignments, tokenizers, transformers, spacy_transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.1
#     Uninstalling transformers-4.57.1:
#       Successfully uninstalled transformers-4.57.1
# Successfully installed spacy-alignments-0.9.2 spacy_transformers-1.3.9 tokenizers-0.21.4 transformers-4.49.0
# Collecting en-core-web-trf==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.8.0/en_core_web_trf-3.8.0-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 1.3 MB/s eta 0:00:00
# Collecting spacy-curated-transformers<1.0.0,>=0.2.2 (from en-core-web-trf==3.8.0)
#   Downloading spacy_curated_transformers-0.3.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting curated-transformers<0.2.0,>=0.1.0 (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0)
#   Downloading curated_transformers-0.1.1-py2.py3-none-any.whl.metadata (965 bytes)
# Collecting curated-tokenizers<0.1.0,>=0.0.9 (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0)
#   Downloading curated_tokenizers-0.0.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2.9.0+cu126)
# Requirement already satisfied: regex>=2022 in /usr/local/lib/python3.12/dist-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2024.11.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.0.3)
# Downloading spacy_curated_transformers-0.3.1-py2.py3-none-any.whl (237 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.9/237.9 kB 15.1 MB/s eta 0:00:00
# Downloading curated_tokenizers-0.0.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (734 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.0/734.0 kB 45.6 MB/s eta 0:00:00
# Downloading curated_transformers-0.1.1-py2.py3-none-any.whl (25 kB)
# Installing collected packages: curated-tokenizers, curated-transformers, spacy-curated-transformers, en-core-web-trf
# Successfully installed curated-tokenizers-0.0.9 curated-transformers-0.1.1 en-core-web-trf-3.8.0 spacy-curated-transformers-0.3.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
#
# ✅ Dependencies installed successfully!

# %% [markdown]
# ## Step 3: Check GPU Availability

# %%
import torch

# Check if GPU is available
if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    print(f"✅ GPU Available: {gpu_name}")
    print(f"   Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
    use_gpu = 0
else:
    print("⚠️  No GPU available, will use CPU (slower)")
    print("   To enable GPU: Runtime → Change runtime type → GPU")
    use_gpu = -1

print(f"\n🎯 Training will use: {'GPU' if use_gpu >= 0 else 'CPU'}")
# Out:
# ✅ GPU Available: Tesla T4
#    Memory: 15.83 GB
#
# 🎯 Training will use: GPU

# %% [markdown]
# ## Step 4: Verify Training Files
#
# All files are already synced to Google Drive! Let's verify they exist.

# %%
# Verify all files are in Google Drive
print("📁 Checking training files...\n")

# Check training data
print("Training Data:")
# !ls -lh "$PROJECT_PATH/nlp/training_data/spacy/"

print("\nConfiguration:")
# !ls -lh "$PROJECT_PATH/nlp/configs/"

print("\n✅ All files are ready in Google Drive!")
# Out:
# 📁 Checking training files...
#
# Training Data:
# total 130K
# -rw------- 1 root root  30K Nov 21 18:42 dev.spacy
# -rw------- 1 root root 100K Nov 22 20:26 train.spacy
#
# Configuration:
# total 8.0K
# -rw------- 1 root root 7.8K Nov 22 20:01 config.cfg
#
# ✅ All files are ready in Google Drive!

# %% [markdown]
# ## Step 5: Final Verification
#
# Let's double-check all required files are present and ready for training.

# %%
import os

# Check all required files
required_files = [
    f"{PROJECT_PATH}/nlp/training_data/spacy/train.spacy",
    f"{PROJECT_PATH}/nlp/training_data/spacy/dev.spacy",
    f"{PROJECT_PATH}/nlp/configs/config.cfg"
]

print("📋 Checking required files:\n")
all_present = True
for filepath in required_files:
    if os.path.exists(filepath):
        size = os.path.getsize(filepath) / 1024
        print(f"✅ {filepath} ({size:.1f} KB)")
    else:
        print(f"❌ {filepath} (MISSING)")
        all_present = False

if all_present:
    print("\n🎉 All files present! Ready to train.")
else:
    print("\n⚠️  Some files are missing. Please upload them first.")
# Out:
# 📋 Checking required files:
#
# ✅ /content/drive/MyDrive/Helixgraph/nlp/training_data/spacy/train.spacy (99.7 KB)
# ✅ /content/drive/MyDrive/Helixgraph/nlp/training_data/spacy/dev.spacy (29.4 KB)
# ✅ /content/drive/MyDrive/Helixgraph/nlp/configs/config.cfg (7.7 KB)
#
# 🎉 All files present! Ready to train.

# %% [markdown]
# ## Step 6: Start Training! 🚀
#
# This will take 30-45 minutes on GPU, or 2-3 hours on CPU.

# %%
# Change to project directory
os.chdir(PROJECT_PATH)

# Create output directory
# !mkdir -p nlp/models/ner_model

# Start training
print("🚀 Starting NER model training...\n")
print(f"   Using: {'GPU' if use_gpu >= 0 else 'CPU'}")
print(f"   Config: {PROJECT_PATH}/nlp/configs/config.cfg")
print(f"   Output: {PROJECT_PATH}/nlp/models/ner_model\n")
print("=" * 60)

# !python -m spacy train \
    nlp/configs/config.cfg \
    --output nlp/models/ner_model \
    --paths.train nlp/training_data/spacy/train.spacy \
    --paths.dev nlp/training_data/spacy/dev.spacy \
    --gpu-id $use_gpu

print("\n" + "=" * 60)
print("✅ Training completed!")
# Out:
# 🚀 Starting NER model training...
#
#    Using: GPU
#    Config: /content/drive/MyDrive/Helixgraph/nlp/configs/config.cfg
#    Output: /content/drive/MyDrive/Helixgraph/nlp/models/ner_model
#
# ============================================================
# ℹ Saving to output directory: nlp/models/ner_model
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 135kB/s]
# config.json: 100% 481/481 [00:00<00:00, 3.78MB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 4.10MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 2.13MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 3.21MB/s]
# 2025-11-22 21:00:49.817601: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763845249.849842    5240 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763845249.859786    5240 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763845249.884101    5240 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763845249.884131    5240 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763845249.884139    5240 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763845249.884145    5240 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-22 21:00:49.889334: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors: 100% 499M/499M [00:03<00:00, 151MB/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
# /usr/local/lib/python3.12/dist-packages/thinc/util.py:395: VisibleDeprecationWarning: This function is deprecated and will be removed in a future release. Use the cupy.from_dlpack() array constructor instead.
#   dlpack_tensor = xp_tensor.toDlpack()  # type: ignore
#   0       0          38.86     40.43    0.13    0.09    0.21    0.00
#   1     200        4523.58   4124.04   61.30   60.24   62.39    0.61
#   2     400         619.13    702.84   94.84   95.14   94.54    0.95
#   3     600         159.23    172.08   96.54   96.44   96.64    0.97
#   6     800          69.64     64.77   98.22   98.11   98.32    0.98
#   8    1000          10.12     10.32   99.27   99.16   99.37    0.99
#  11    1200           8.27     12.88   99.16   99.16   99.16    0.99
#  15    1400          36.89     28.97   99.58   99.58   99.58    1.00
#  20    1600           9.14      9.06   99.58   99.58   99.58    1.00
#  25    1800          68.51     40.78   99.37   99.37   99.37    0.99
#  32    2000          36.81     24.83   99.48   99.37   99.58    0.99
#  41    2200          14.49     11.18   99.58   99.58   99.58    1.00
#  51    2400          73.35     46.18   99.58   99.58   99.58    1.00
#  62    2600        2491.97   1604.63   99.27   99.16   99.37    0.99
#  72    2800          29.01     22.19   99.58   99.58   99.58    1.00
#  83    3000          26.04     21.68   98.74   98.74   98.74    0.99
#  93    3200          10.57      8.63   99.27   99.16   99.37    0.99
# 104    3400           4.77      3.96   99.37   99.37   99.37    0.99
# 114    3600           8.80     11.24   99.58   99.58   99.58    1.00
# 125    3800          17.06     15.84   99.48   99.37   99.58    0.99
# 136    4000          12.13      9.38   99.69   99.58   99.79    1.00
# 146    4200          27.08     24.04   99.37   99.37   99.37    0.99
# 157    4400          15.52     10.39   99.58   99.58   99.58    1.00
# 167    4600         220.48    132.81   99.58   99.58   99.58    1.00
# 178    4800          16.41     12.53   99.58   99.58   99.58    1.00
# 188    5000          21.35     10.53   99.37   99.37   99.37    0.99
# 199    5200           2.61      5.13   99.37   99.37   99.37    0.99
# 209    5400          15.57      7.79   99.48   99.37   99.58    0.99
# 220    5600           0.60      2.37   99.37   99.37   99.37    0.99
# 230    5800          20.57     15.16   99.27   99.16   99.37    0.99
# 241    6000           4.33      4.43   99.58   99.58   99.58    1.00
# 251    6200        1039.97    616.78   99.79   99.79   99.79    1.00
# 262    6400          16.70     11.26   99.48   99.37   99.58    0.99
# 272    6600          27.31     20.29   99.58   99.58   99.58    1.00
# 283    6800           0.11      0.12   99.58   99.58   99.58    1.00
# 293    7000           0.11      0.17   99.58   99.58   99.58    1.00
# 304    7200           3.69      1.97   99.58   99.58   99.58    1.00
# 314    7400           3.02      2.04   99.58   99.58   99.58    1.00
# 325    7600           5.38      9.56   99.37   99.37   99.37    0.99
# 336    7800          14.73     12.02   99.58   99.58   99.58    1.00
# 346    8000          16.28     15.48   99.58   99.58   99.58    1.00
# 357    8200           3.00      0.97   99.48   99.37   99.58    0.99
# 367    8400           0.00      0.00   99.48   99.37   99.58    0.99
# 378    8600           0.00      0.00   99.48   99.37   99.58    0.99
# 388    8800          55.53     50.17   99.37   99.37   99.37    0.99
# 399    9000          11.24      9.21   99.06   98.95   99.16    0.99
# 409    9200          41.49     30.18   99.16   98.95   99.37    0.99
# ✔ Saved pipeline to output directory
# nlp/models/ner_model/model-last
#
# ============================================================
# ✅ Training completed!

# %% [markdown]
# ## Step 7: Evaluate Model

# %%
print("📊 Evaluating model on dev set...\n")

# !python -m spacy evaluate \
    nlp/models/ner_model/model-best \
    nlp/training_data/spacy/dev.spacy \
    --gpu-id $use_gpu

print("\n✅ Evaluation complete!")
# Out:
# 📊 Evaluating model on dev set...
#
# ℹ Using GPU: 0
# 2025-11-22 22:05:26.572554: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763849126.605692   21600 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763849126.616036   21600 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763849126.640238   21600 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763849126.640279   21600 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763849126.640288   21600 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763849126.640295   21600 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-22 22:05:26.647333: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ================================== Results ==================================
#
# TOK     100.00
# NER P   99.79
# NER R   99.79
# NER F   99.79
# SPEED   772
#
#
# =============================== NER (per type) ===============================
#
#                 P        R        F
# SUPPLIER    98.75    98.75    98.75
# CONTRACT   100.00   100.00   100.00
# PO         100.00   100.00   100.00
# ROLE       100.00   100.00   100.00
# SKILL      100.00   100.00   100.00
# CAMPAIGN   100.00   100.00   100.00
# PRODUCT    100.00   100.00   100.00
# INVOICE    100.00   100.00   100.00
#
#
# ✅ Evaluation complete!

# %% [markdown]
# ## Step 8: Test Model with Sample Inputs

# %%
import spacy
from spacy import displacy

# Load trained model
print("📦 Loading trained model...")
nlp = spacy.load(f"{PROJECT_PATH}/nlp/models/ner_model/model-best")
print("✅ Model loaded!\n")

# Test sentences
test_sentences = [
    "The Marketing Coordinator managed the Nike Summer Sale campaign successfully.",
    "Invoice INV-123456 from Tech Suppliers Ltd was paid via PO-789012 last month.",
    "Our Software Engineer with Python expertise led the campaign optimization project.",
    "Contract CTR-445566 with Global Procurement Inc covers delivery of office supplies."
]

print("🧪 Testing model with sample sentences:\n")
print("=" * 80)

for i, text in enumerate(test_sentences, 1):
    doc = nlp(text)

    print(f"\n{i}. {text}")
    print(f"   Entities found: {len(doc.ents)}")

    if doc.ents:
        for ent in doc.ents:
            print(f"     - [{ent.label_}] '{ent.text}'")
    else:
        print("     (No entities detected)")

    print("-" * 80)

print("\n✅ Model testing complete!")
# Out:
# 📦 Loading trained model...
# ✅ Model loaded!
#
# 🧪 Testing model with sample sentences:
#
# ================================================================================
#
# 1. The Marketing Coordinator managed the Nike Summer Sale campaign successfully.
#    Entities found: 2
#      - [ROLE] 'Marketing Coordinator'
#      - [CAMPAIGN] 'Nike Summer Sale'
# --------------------------------------------------------------------------------
#
# 2. Invoice INV-123456 from Tech Suppliers Ltd was paid via PO-789012 last month.
#    Entities found: 3
#      - [INVOICE] 'INV-123456'
#      - [SUPPLIER] 'Tech Suppliers Ltd'
#      - [PO] 'PO-789012'
# --------------------------------------------------------------------------------
#
# 3. Our Software Engineer with Python expertise led the campaign optimization project.
#    Entities found: 2
#      - [ROLE] 'Software Engineer'
#      - [SKILL] 'Python'
# --------------------------------------------------------------------------------
#
# 4. Contract CTR-445566 with Global Procurement Inc covers delivery of office supplies.
#    Entities found: 2
#      - [CONTRACT] 'CTR-445566'
#      - [SUPPLIER] 'Global Procurement Inc'
# --------------------------------------------------------------------------------
#
# ✅ Model testing complete!

# %% [markdown]
# ## Step 9: Visualize Entity Recognition

# %%
# Visualize entities in a sample sentence
sample_text = "The Product Manager with SQL and Leadership skills managed the Apple iPhone Launch campaign and approved invoice INV-998877 from Tech Solutions via PO-112233."

doc = nlp(sample_text)

print("🎨 Entity Visualization:\n")
displacy.render(doc, style="ent", jupyter=True)

print("\n📋 Detected Entities:")
for ent in doc.ents:
    print(f"   [{ent.label_:12}] {ent.text}")
# Out:
# 🎨 Entity Visualization:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Product Manager
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ROLE</span>
# </mark>
#  with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SQL and Leadership
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  skills managed the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple iPhone Launch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CAMPAIGN</span>
# </mark>
#  campaign and approved invoice
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     INV-998877
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INVOICE</span>
# </mark>
#  from
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tech Solutions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SUPPLIER</span>
# </mark>
#  via
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PO-112233
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PO</span>
# </mark>
# .</div></span>
# 📋 Detected Entities:
#    [ROLE        ] Product Manager
#    [SKILL       ] SQL and Leadership
#    [CAMPAIGN    ] Apple iPhone Launch
#    [INVOICE     ] INV-998877
#    [SUPPLIER    ] Tech Solutions
#    [PO          ] PO-112233

# %% [markdown]
# ## Step 10: View Training Metrics

# %%
import json
from datetime import datetime

# Check if training metrics file exists
metrics_file = f"{PROJECT_PATH}/nlp/models/ner_model/model-best/meta.json"

if os.path.exists(metrics_file):
    with open(metrics_file, 'r') as f:
        meta = json.load(f)

    print("📊 Training Metrics:")
    print("=" * 60)

    if 'performance' in meta:
        perf = meta['performance']
        print(f"\n🎯 Overall Performance:")
        for key, value in perf.items():
            if isinstance(value, float):
                print(f"   {key:20} : {value:.4f}")

    print("\n" + "=" * 60)
    print(f"✅ Model saved to: {PROJECT_PATH}/nlp/models/ner_model/model-best")
else:
    print("⚠️  Metrics file not found")
# Out:
# 📊 Training Metrics:
# ============================================================
#
# 🎯 Overall Performance:
#    ents_f               : 0.9979
#    ents_p               : 0.9979
#    ents_r               : 0.9979
#    transformer_loss     : 1039.9667
#    ner_loss             : 616.7777
#
# ============================================================
# ✅ Model saved to: /content/drive/MyDrive/Helixgraph/nlp/models/ner_model/model-best

# %% [markdown]
# ## Step 11: Download Trained Model (Optional)
#
# Download the trained model to your local machine for later use.

# %%
from google.colab import files

# Create a zip file of the trained model
model_path = f"{PROJECT_PATH}/nlp/models/ner_model/model-best"
zip_path = f"{PROJECT_PATH}/ner_model_trained.zip"

print("📦 Creating zip file...")
# !cd "$PROJECT_PATH" && zip -r ner_model_trained.zip nlp/models/ner_model/model-best/

print("\n📥 Download the model:")
files.download(zip_path)

print("✅ Model downloaded!")
# Out:
# 📦 Creating zip file...
# updating: nlp/models/ner_model/model-best/ (stored 0%)
# updating: nlp/models/ner_model/model-best/tokenizer (deflated 81%)
# updating: nlp/models/ner_model/model-best/meta.json (deflated 69%)
# updating: nlp/models/ner_model/model-best/config.cfg (deflated 62%)
# updating: nlp/models/ner_model/model-best/transformer/ (stored 0%)
# updating: nlp/models/ner_model/model-best/transformer/cfg (stored 0%)
# updating: nlp/models/ner_model/model-best/transformer/model (deflated 15%)
# updating: nlp/models/ner_model/model-best/ner/ (stored 0%)
# updating: nlp/models/ner_model/model-best/ner/model (deflated 8%)
# updating: nlp/models/ner_model/model-best/ner/moves (deflated 68%)
# updating: nlp/models/ner_model/model-best/ner/cfg (deflated 33%)
# updating: nlp/models/ner_model/model-best/vocab/ (stored 0%)
# updating: nlp/models/ner_model/model-best/vocab/strings.json (deflated 72%)
# updating: nlp/models/ner_model/model-best/vocab/vectors (deflated 45%)
# updating: nlp/models/ner_model/model-best/vocab/key2row (stored 0%)
# updating: nlp/models/ner_model/model-best/vocab/vectors.cfg (stored 0%)
# updating: nlp/models/ner_model/model-best/vocab/lookups.bin (stored 0%)
#
# 📥 Download the model:
# ✅ Model downloaded!

# %% [markdown]
# ## Summary
#
# ### ✅ Training Complete!
#
# Your NER model has been trained successfully on Google Colab.
#
# **Model Location:** `{PROJECT_PATH}/nlp/models/ner_model/model-best`
#
# **Next Steps:**
# 1. Review evaluation metrics above
# 2. Test with your own sentences
# 3. Download model for local use
# 4. Integrate into FastAPI (Phase 4)
#
# **Model Capabilities:**
# - Recognizes 8 entity types across 3 business domains
# - Cross-domain entity recognition
# - Based on RoBERTa transformer
# - Ready for production use
